# %%
import os
from dotenv import load_dotenv
import numpy as np
import pandas as pd
import matplotlib as plt
from airtable import Airtable
load_dotenv()

# Loading in Airtable
API_KEY = os.getenv('AIRTABLE_API_KEY')
BASE_KEY = os.getenv('AIRTABLE_BASE_KEY')
table_name = 'Directory'
airtable = Airtable(BASE_KEY, table_name, API_KEY)

# %%
# Get all records
records = airtable.get_all()
df = pd.DataFrame.from_records((r['fields'] for r in records))
df.shape
# Out:
# (144, 20)

# %%
# Iterating through columns
for col in df.columns:
    print(col)
# Out:
# First Name
# Last Name
# NetID
# Graduation Year
# Pledge Semester
# Major(s)
# Phone Number
# Preferred Email
# Illinois Email
# Personal Email
# Home Address
# Campus Address
# Birthday
# Minor(s)
# Study Abroad
# Internship Company(s)
# Internship Date(s)
# Leadership Conferences
# Job Shadows
# Organizations

# %%
# Plotting pie chart of graduation years
df['Graduation Year'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(8,8))
# Out:
# <AxesSubplot:ylabel='Graduation Year'>

# %%
df['Preferred Email'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(8,8))
# Out:
# <AxesSubplot:ylabel='Preferred Email'>

# %%
df['Pledge Semester'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(8,8))
# Out:
# <AxesSubplot:ylabel='Pledge Semester'>

# %%
# Insight Ideas
# Internship Placement Rate (parse internship dates for year, divide count by grade or total actives)
# Full-Time Placement Rate
# Engineers x Females or Engineers x Males
# ICG Involvement -> Consulting Org Placement
